# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

superstore=pd.read_excel(r'C:\Users\balls\OneDrive\Documents\Developers_insititute\Learn_python\DI_Bootcamp\week3\day5\mini project\US Superstore data.xls')
superstore.info()
superstore.describe()
superstore.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
superstore.duplicated().sum()
# Out:
# np.int64(0)

# %%
superstore.drop(columns=['Row ID','Country'],inplace=True)

# %%
import datetime
superstore['Order Date']=pd.to_datetime(superstore['Order Date'])
superstore['Ship Date']=pd.to_datetime(superstore['Ship Date'])

# %%
superstore.nunique()
# Out:
# Order ID         5009
# Order Date       1237
# Ship Date        1334
# Ship Mode           4
# Customer ID       793
# Customer Name     793
# Segment             3
# City              531
# State              49
# Postal Code       631
# Region              4
# Product ID       1862
# Category            3
# Sub-Category       17
# Product Name     1850
# Sales            6144
# Quantity           14
# Discount           12
# Profit           7545
# dtype: int64

# %%
superstore.head()
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
#
#   Region       Product ID         Category Sub-Category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
state_sales=superstore.groupby('State',as_index=False)['Sales'].sum().sort_values('Sales',ascending=False)
state_sales.reset_index(drop=True,inplace=True)
print(f"Top state sales {state_sales.loc[0,'State']} - ${state_sales.loc[0,'Sales']:,.1f}")
# Out:
# Top state sales California - $457,687.6

# %%
state_sales_profit=superstore.groupby('State',as_index=False)[['Sales','Profit']].sum().sort_values(['Sales','Profit'],ascending=[False, False])
state_sales_profit.set_index('State',inplace=True)
# state_sales_profit.head()
ny_sales, ny_profit=state_sales_profit.loc['New York',['Sales','Profit']].round(1)
ca_sales, ca_profit=state_sales_profit.loc['California',['Sales','Profit']].round(1)
print (f'New York sales {ny_sales:,.1f}, profit {ny_profit:,.1f}')
print (f'California sales {ca_sales:,.1f}, profit {ca_profit:,.1f}')
print (f'California made {(ca_sales-ny_sales):,.1f} more sales than New York')
print (f'California made {(ca_profit-ny_profit):,.1f} more profit than New York')
# Out:
# New York sales 310,876.3, profit 74,038.5
# California sales 457,687.6, profit 76,381.4
# California made 146,811.3 more sales than New York
# California made 2,342.9 more profit than New York

# %%
customer=superstore.loc[superstore['State']=='New York']
customer=customer.groupby(['Customer ID','Customer Name'],as_index=False)['Sales'].sum()
customer.sort_values('Sales',ascending=False,inplace=True)
customer.reset_index(drop=True,inplace=True)
print(f"Top customer in New York is {customer.loc[0,'Customer Name']} - ${customer.loc[0,'Sales']:,.1f}")
# Out:
# Top customer in New York is Tom Ashbrook - $13,723.5

# %%
# state_perf = (superstore.groupby('State', as_index=False)
#              .agg(Sales=('Sales','sum'),
#                   Profit=('Profit','sum')))

profitability=superstore.groupby("State", as_index=False)[['Sales','Profit']].sum()
profitability.reset_index(drop=True,inplace=True)
profitability['Profitability']=(profitability['Profit']/profitability['Sales'])*100
profitability.sort_values(['Profitability'],ascending=False, inplace=True)
profitability.reset_index(drop=True,inplace=True)
print(profitability[['State','Profitability']].head(5).to_string(index=False, formatters={'Profitability': '{:.1f}%'.format}))
print(profitability[['State','Profitability']].tail(5).to_string(index=False, formatters={'Profitability': '{:.1f}%'.format}))
profitability_negative=profitability[profitability['Profitability']<0]
profitability_negative
print(f'States with negative total profit:', ",  ".join(profitability_negative["State"]))
# profitability.tail(20)
# Out:
#                State Profitability
# District of Columbia         37.0%
#             Delaware         36.3%
#            Minnesota         36.2%
#                Maine         35.8%
#             Arkansas         34.3%
#     State Profitability
#     Texas        -15.1%
#  Illinois        -15.7%
# Tennessee        -17.4%
#  Colorado        -20.3%
#      Ohio        -21.7%
# States with negative total profit: Florida,  Oregon,  Arizona,  Pennsylvania,  North Carolina,  Texas,  Illinois,  Tennessee,  Colorado,  Ohio

# %%
# Top 20 customers
customer_profit=superstore.groupby(['Customer ID','Customer Name'],as_index=False)[['Sales','Profit',]].sum()
customer_p=customer_profit.sort_values(['Profit'],ascending=False).reset_index(drop=True)
customer_s=customer_profit.sort_values(['Sales'],ascending=False).reset_index(drop=True)
sales=superstore['Sales'].sum()
profit=superstore['Profit'].sum()
print(f'Total sales {sales:,.1f}')
print(f'Total profit {profit:,.1f}')
customer_p['Profit%']=(customer_p['Profit']/profit)*100
customer_s['Sales%']=(customer_s['Sales']/sales)*100
customer20=int((len(customer_p)/100)*20)
top20=customer_p.head(customer20)
top20_s=customer_s.head(customer20)
customer_p_sum_per=top20['Profit%'].sum()
customer_p_sum=top20['Profit'].sum()
customer_s_sum=top20_s['Sales'].sum()
customer_s_sum_per=top20_s['Sales%'].sum()

# print(customer_p.head(int(customer20)))
print(f'Top 20% customers bring {customer_p_sum_per:,.1f}% of profit, {customer_p_sum:,.1f}$')
print(f'Top 20% customers bring {customer_s_sum_per:,.1f}% of sales, {customer_s_sum:,.1f}$')

print(f'Top 20 customers by Sales\n{customer_s.head(20)}')
print(f'Top 20 customers by Profit\n{customer_p.head(20)}')
# Out:
# Total sales 2,297,200.9
# Total profit 286,397.0
# Top 20% customers bring 81.4% of profit, 233,201.3$
# Top 20% customers bring 48.0% of sales, 1,101,781.4$
# Top 20 customers by Sales
#    Customer ID       Customer Name      Sales     Profit    Sales%
# 0     SM-20320         Sean Miller  25043.050 -1980.7393  1.090155
# 1     TC-20980        Tamara Chand  19052.218  8981.3239  0.829367
# 2     RB-19360        Raymond Buch  15117.339  6976.0959  0.658076
# 3     TA-21385        Tom Ashbrook  14595.620  4703.7883  0.635365
# 4     AB-10105       Adrian Barton  14473.571  5444.8055  0.630052
# 5     KL-16645        Ken Lonsdale  14175.229   806.8550  0.617065
# 6     SC-20095        Sanjit Chand  14142.334  5757.4119  0.615633
# 7     HL-15040        Hunter Lopez  12873.298  5622.4292  0.560391
# 8     SE-20110        Sanjit Engle  12209.438  2650.6769  0.531492
# 9     CC-12370  Christopher Conant  12129.072  2177.0493  0.527994
# ...

# %%
#Top 20 Sub-Category
import math
sub_category=superstore.groupby('Sub-Category',as_index=False)[['Sales','Profit']].sum().sort_values('Profit',ascending=False).reset_index(drop=True)
sub_category
top20index=math.ceil((len(sub_category)/100)*20)
top20_category=sub_category.head(top20index)
top20_category['Profit%']=(top20_category['Profit']/profit)*100
top20_profit_sum=top20_category['Profit%'].sum()
print(f'Top 20% categories bring {top20_profit_sum:,.1f}% of profit')
print(top20_category.head())
# Out:
# Top 20% categories bring 61.5% of profit
#   Sub-Category       Sales      Profit    Profit%
# 0      Copiers  149528.030  55617.8249  19.419834
# 1       Phones  330007.054  44515.7306  15.543364
# 2  Accessories  167380.318  41936.6357  14.642832
# 3        Paper   78479.206  34053.5693  11.890336
# C:\Users\balls\AppData\Local\Temp\ipykernel_14624\4096168513.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top20_category['Profit%']=(top20_category['Profit']/profit)*100

# %%
#Citys Sales Profit and Profitability
df_city=superstore.groupby('City',as_index=False)[['Sales','Profit']].sum()
city_sales=df_city.sort_values('Sales',ascending=False).reset_index(drop=True)
city_profit=df_city.sort_values('Profit',ascending=False).reset_index(drop=True)
city_profit['Profit%']=(city_profit['Profit']/profit)*100
city_sales['Sales%']=(city_sales['Sales']/sales)*100
city_profit['Profitability']=(city_profit['Profit']/city_profit['Sales'])*100
city_sales['Profitability']=(city_sales['Profit']/city_sales['Sales'])*100
top20_sales=city_sales.head(20)
top20_profit=city_profit.head(20)
print(f' Top 20 cities by sale\n{city_sales.head(20)}')
print(f' Top 20 cities by profit\n{city_profit.head(20)}')
# Out:
#  Top 20 cities by sale
#              City        Sales      Profit     Sales%  Profitability
# 0   New York City  256368.1610  62036.9837  11.160024      24.198396
# 1     Los Angeles  175851.3410  30440.7579   7.655027      17.310507
# 2         Seattle  119540.7420  29156.0967   5.203757      24.390092
# 3   San Francisco  112669.0920  17507.3854   4.904625      15.538765
# 4    Philadelphia  109077.0130 -13837.7674   4.748258     -12.686236
# 5         Houston   64504.7604 -10153.5485   2.807972     -15.740774
# 6         Chicago   48539.5410  -6654.5688   2.112986     -13.709583
# 7       San Diego   47521.0290   6377.1960   2.068649      13.419735
# 8    Jacksonville   44713.1830  -2323.8350   1.946420      -5.197203
# 9     Springfield   43054.3420   6200.6974   1.874209      14.402026
# 10        Detroit   42446.9440  13181.7908   1.847768      31.054746
# 11       Columbus   38706.2430   5897.1013   1.684931      15.235530
# ...

# %%
sales_only=(top20_sales[top20_sales['City'].isin(top20_profit['City'])])
sales_only_ex=(top20_sales[~top20_sales['City'].isin(top20_profit['City'])])

print(f'From top 20 cities sales only {len(sales_only)} ({", ".join(sales_only["City"])}) is in top 20 cities by profit')
print(f'In {len(sales_only_ex)} cities ({", ".join(sales_only_ex["City"])}) sales are high but low profit')
# Out:
# From top 20 cities sales only 13 (New York City, Los Angeles, Seattle, San Francisco, San Diego, Springfield, Detroit, Columbus, Newark, Columbia, Lafayette, Jackson, Arlington) is in top 20 cities by profit
# In 7 cities (Philadelphia, Houston, Chicago, Jacksonville, San Antonio, Burlington, Dallas) sales are high but low profit

# %%
city_perf = (superstore.groupby('City', as_index=False)
             .agg(Sales=('Sales','sum'), Profit=('Profit','sum')))
city_perf['Profit%'] = np.where(
    city_perf['Sales'] > 0,
    city_perf['Profit'] / city_perf['Sales'] * 100,
    np.nan
)

# 2) Топ-20 по продажам и по прибыли
top20_sales  = city_perf.sort_values('Sales',  ascending=False).head(20)
top20_profit = city_perf.sort_values('Profit', ascending=False).head(20)

# 3) Анализ profitability среди городов из обоих топов
union_cities = pd.Index(top20_sales['City']).union(top20_profit['City'])
union_perf = (city_perf.set_index('City')
                        .loc[union_cities]
                        .reset_index())

# Размах маржи и убытки
pm = union_perf['Profit%']
spread = pm.max() - pm.min()
loss = union_perf[union_perf['Profit'] < 0][['City','Sales','Profit','Profit%']]

print(f"Cities considered: {len(union_perf)}")
print(f"Profitability spread (max - min): {spread:.2f} percentage points")

if len(loss):
    print("\nLoss-making cities within the top lists:")
    print(loss.sort_values('Profit')
             .to_string(index=False,
                        formatters={'Sales':'{:,.0f}'.format,
                                    'Profit':'{:,.0f}'.format,
                                    'Profit%':'{:.2f}%'.format}))
else:
    print("\nNo loss-making cities within the top lists.")

# Топ/низ по марже в объединённом списке
print("\nTop 5 cities by Profit Margin (within union):")
print(union_perf.sort_values('Profit%', ascending=False)
      .head(5)[['City','Sales','Profit','Profit%']]
      .to_string(index=False,
                 formatters={'Sales':'{:,.0f}'.format,
                             'Profit':'{:,.0f}'.format,
                             'Profit%':'{:.2f}%'.format}))

print("\nBottom 5 cities by Profit Margin (within union):")
print(union_perf.sort_values('Profit%', ascending=True)
      .head(5)[['City','Sales','Profit','Profit%']]
      .to_string(index=False,
                 formatters={'Sales':'{:,.0f}'.format,
                             'Profit':'{:,.0f}'.format,
                             'Profit%':'{:.2f}%'.format}))

# 4) Несовпадения списков: «много продаж, но не топ по прибыли» и наоборот
sales_only = (top20_sales[~top20_sales['City'].isin(top20_profit['City'])])
profit_only = (top20_profit[~top20_profit['City'].isin(top20_sales['City'])])

print(f"\nTop-20 Sales only (count={len(sales_only)}):")
print(sales_only[['City','Sales','Profit%']]
      .to_string(index=False,
                 formatters={'Sales':'{:,.0f}'.format,'Profit%':'{:.2f}%'.format}))

print(f"\nTop-20 Profit only (count={len(profit_only)}):")
print(profit_only[['City','Profit','Profit%']]
      .to_string(index=False,
                 formatters={'Profit':'{:,.0f}'.format,'Profit%':'{:.2f}%'.format}))
# Out:
# Cities considered: 27
# Profitability spread (max - min): 74.08 percentage points
#
# Loss-making cities within the top lists:
#         City   Sales  Profit Profit%
# Philadelphia 109,077 -13,838 -12.69%
#      Houston  64,505 -10,154 -15.74%
#  San Antonio  21,844  -7,299 -33.42%
#      Chicago  48,540  -6,655 -13.71%
#   Burlington  21,668  -3,623 -16.72%
#       Dallas  20,132  -2,847 -14.14%
# Jacksonville  44,713  -2,324  -5.20%
#
# Top 5 cities by Profit Margin (within union):
#        City  Sales Profit Profit%
#     Atlanta 17,198  6,994  40.67%
# Minneapolis 16,871  6,825  40.45%
#   Lafayette 25,036 10,018  40.02%
#  Providence 15,981  5,506  34.45%
#     Detroit 42,447 13,182  31.05%
#
# Bottom 5 cities by Profit Margin (within union):
#        City  Sales  Profit Profit%
# San Antonio 21,844  -7,299 -33.42%
#  Burlington 21,668  -3,623 -16.72%
#     Houston 64,505 -10,154 -15.74%
#      Dallas 20,132  -2,847 -14.14%
#     Chicago 48,540  -6,655 -13.71%
#
# ...

# %%
(superstore.groupby('State', as_index=False)
   .agg(Sales=('Sales','sum'),
        Profit=('Profit','sum'),
        Orders=('Order ID','nunique')))
# Out:
#                    State        Sales      Profit  Orders
# 0                Alabama   19510.6400   5786.8253      34
# 1                Arizona   35282.0010  -3427.9246     108
# 2               Arkansas   11678.1300   4008.6871      27
# 3             California  457687.6315  76381.3871    1021
# 4               Colorado   32108.1180  -6527.8579      79
# 5            Connecticut   13384.3570   3511.4918      45
# 6               Delaware   27451.0690   9977.3748      44
# 7   District of Columbia    2865.0200   1059.5893       4
# 8                Florida   89473.7080  -3399.3017     200
# 9                Georgia   49095.8400  16250.0433      91
# 10                 Idaho    4382.4860    826.7231      11
# 11              Illinois   80166.1010 -12607.8870     276
# 12               Indiana   53555.3600  18382.9363      73
# 13                  Iowa    4579.7600   1183.8119      17
# 14                Kansas    2914.3100    836.4435      14
# ...

# %%
# Подготовка (если хочешь обращаться к штату как к метке строки):
sp = superstore.set_index('State')      # индекс = State
# print(sp)
sp.loc['California', ['Sales','Profit']]
# sp.loc[['California','New York'], 'Sales']  # несколько меток
# Out:
#               Sales   Profit
# State
# California   14.620   6.8714
# California   48.860  14.1694
# California    7.280   1.9656
# California  907.152  90.7152
# California   18.504   5.7825
# ...             ...      ...
# California   36.240  15.2208
# California   91.960  15.6332
# California  258.576  19.3932
# California   29.600  13.3200
# California  243.160  72.9480
#
# [2001 rows x 2 columns]

# %%
# Фильтр по условию(ям):
# Важно: скобки и & | ~ вместо and/or/not
mask = (superstore['State']=='California') & (superstore['Category']=='Technology')
# print(mask)
superstore.loc[mask, ['City','Sales','Profit']]
# Out:
#                City    Sales   Profit
# 7       Los Angeles  907.152  90.7152
# 11      Los Angeles  911.424  68.3568
# 19    San Francisco  213.480  16.0110
# 26      Los Angeles   90.570  11.7741
# 62      Los Angeles   13.980   6.1512
# ...             ...      ...      ...
# 9941  San Francisco  223.580  87.1962
# 9973    Los Angeles  271.960  27.1960
# 9976    Los Angeles  249.584  31.1980
# 9986    Los Angeles   36.240  15.2208
# 9991     Costa Mesa  258.576  19.3932
#
# [359 rows x 3 columns]

# %%
# Срезы по меткам (label-slice, включительно по правой границе):
ts = superstore.set_index('Order Date').sort_index()
# print(ts)
ts.loc['2017-01':'2017-03', ['Sales','Profit']]   # Янв–Март включительно
# Out:
#                Sales    Profit
# Order Date
# 2017-01-01    3.6000    1.7280
# 2017-01-01   48.8960    8.5568
# 2017-01-01  474.4300  199.2606
# 2017-01-01  310.7440  -26.6352
# 2017-01-01   12.7360    2.2288
# ...              ...       ...
# 2017-03-31   84.9500   22.0870
# 2017-03-31   29.7800    8.0406
# 2017-03-31   75.0400   36.0192
# 2017-03-31  205.3328  -36.2352
# 2017-03-31  677.5800  176.1708
#
# [500 rows x 2 columns]

# %%
# Взять одно «скалярное» значение:
# Если ровно одна строка удовлетворяет условию
val = superstore.loc[superstore['City']=='Los Angeles', 'Sales'].iloc[0]  # .iloc[0] к скаляру
print(val)
# или быстрее, когда индекс — метка строки:
sp.at['California','Sales']   # .at — оптимизировано для одной ячейки

# .loc — по меткам (строки/столбцы по именам).

# .iloc — по позициям (0,1,2…).

# .at/.iat — быстрый доступ/запись одной ячейки (метка/позиц
# Out:
# 14.62
# State
# California     14.620
# California     48.860
# California      7.280
# California    907.152
# California     18.504
#                ...
# California     36.240
# California     91.960
# California    258.576
# California     29.600
# California    243.160
# Name: Sales, Length: 2001, dtype: float64

# %%
# Присвоение без предупреждений (изменение данных):
superstore.loc[superstore['Discount']>0.3, 'Flag'] = 'High discount'
print(superstore.head())
# Out:
#          Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment             City       State  Postal Code  \
# 0      Claire Gute   Consumer        Henderson    Kentucky        42420
# 1      Claire Gute   Consumer        Henderson    Kentucky        42420
# 2  Darrin Van Huff  Corporate      Los Angeles  California        90036
# 3   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
# 4   Sean O'Donnell   Consumer  Fort Lauderdale     Florida        33311
#
#   Region       Product ID         Category Sub-Category  \
# 0  South  FUR-BO-10001798        Furniture    Bookcases
# ...

# %%
# Вытащить топ-города из уже отсортированной таблицы:

city = (superstore.groupby('City', as_index=False)[['Sales','Profit']].sum()
        .sort_values('Sales', ascending=False))
print(city.head())
top20 = city.head(20)
# затем меточным доступом к нужным столбцам
top20.loc[:, ['City','Sales']]
# Out:
#               City       Sales      Profit
# 329  New York City  256368.161  62036.9837
# 266    Los Angeles  175851.341  30440.7579
# 452        Seattle  119540.742  29156.0967
# 438  San Francisco  112669.092  17507.3854
# 374   Philadelphia  109077.013 -13837.7674
#               City        Sales
# 329  New York City  256368.1610
# 266    Los Angeles  175851.3410
# 452        Seattle  119540.7420
# 438  San Francisco  112669.0920
# 374   Philadelphia  109077.0130
# 207        Houston   64504.7604
# 80         Chicago   48539.5410
# 437      San Diego   47521.0290
# 216   Jacksonville   44713.1830
# 464    Springfield   43054.3420
# 123        Detroit   42446.9440
# 94        Columbus   38706.2430
# 330         Newark   28576.1190
# 93        Columbia   25283.3240
# 233      Lafayette   25036.2000
# 215        Jackson   24963.8580
# 434    San Antonio   21843.5280
# 60      Burlington   21668.0820
# 16       Arlington   20214.5320
# 109         Dallas   20131.9322
